# %% [markdown]
# ## Baseball Prediction: 3b - Augment DataFrame with Odds Data
# In the previous notebook we got historical odds data from oddsshark.com and saved them as a set of csv files (with a particular naming convention).
#
# In this notebook we will load that data and augment our primary (game-level) data frame so that it includes this odds data - specifically, the implied probabilities and the over/under, for each game.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lxml
import html5lib
# %matplotlib inline
from urllib.request import urlopen
import time
import structureboost as stb
import ml_insights as mli
pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %% [markdown]
# ## Load in our game level data

# %%
df=pd.read_csv('df_bp1.csv')
# Out:
# /Users/brianlucena/.pyenv/versions/3.9.13/envs/ds3913/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3398: DtypeWarning: Columns (13,14,15,85,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Plan of attack
# - Create a dictionary structure to enable us to easily go to a specific game for a particular team and season.
# - Iterate through the rows of our main dataframe, look up the home and visiting team for that game to get their odds. (Note: need two different lookups per game)

# %% [markdown]
# ## Create a dictionary for easy lookup

# %%
# Use the same mapping as before
# (more elegant to save to file...)

oddsshark_num_to_team_dict = {}
oddsshark_num_to_team_dict[26995]='PHI'
oddsshark_num_to_team_dict[26996]='SDN'
oddsshark_num_to_team_dict[26997]='SFN'
oddsshark_num_to_team_dict[26998]='ANA'
oddsshark_num_to_team_dict[26999]='DET'
oddsshark_num_to_team_dict[27000]='CIN'
oddsshark_num_to_team_dict[27001]='NYA'
oddsshark_num_to_team_dict[27002]='TEX'
oddsshark_num_to_team_dict[27003]='TBA'
oddsshark_num_to_team_dict[27004]='COL'
oddsshark_num_to_team_dict[27005]='MIN'
oddsshark_num_to_team_dict[27006]='KCA'
oddsshark_num_to_team_dict[27007]='ARI'
oddsshark_num_to_team_dict[27008]='BAL'
oddsshark_num_to_team_dict[27009]='ATL'
oddsshark_num_to_team_dict[27010]='TOR'
oddsshark_num_to_team_dict[27011]='SEA'
oddsshark_num_to_team_dict[27012]='MIL'
oddsshark_num_to_team_dict[27013]='PIT'
oddsshark_num_to_team_dict[27014]='NYN'
oddsshark_num_to_team_dict[27015]='LAN'
oddsshark_num_to_team_dict[27016]='OAK'
oddsshark_num_to_team_dict[27017]='WAS'
oddsshark_num_to_team_dict[27018]='CHA'
oddsshark_num_to_team_dict[27019]='SLN'
oddsshark_num_to_team_dict[27020]='CHN'
oddsshark_num_to_team_dict[27021]='BOS'
oddsshark_num_to_team_dict[27022]='MIA'
oddsshark_num_to_team_dict[27023]='HOU'
oddsshark_num_to_team_dict[27024]='CLE'

# %%
# Use the saved files to get the odds information
# We create a dict based on team and season for easy lookup
df_odds_dict={}
for i in range(26995, 27025):
    team_name = oddsshark_num_to_team_dict[i]
    df_odds_dict[team_name] = {}
    print(team_name)
    for season in range(2019,2023):
        fname = 'oddsshark_'+team_name+'_'+str(season)+'.csv'
        df_temp = pd.read_csv(fname)
        df_temp['date_dblhead'] = (df_temp.date_numeric.astype(str) + df_temp.dblheader_num.astype(str)).astype(int)
        df_temp.set_index('date_dblhead', inplace=True)
        df_odds_dict[team_name][season] = df_temp
# Out:
# PHI
# SDN
# SFN
# ANA
# DET
# CIN
# NYA
# TEX
# TBA
# COL
# MIN
# KCA
# ARI
# BAL
# ATL
# TOR
# SEA
# MIL
# PIT
# NYN
# LAN
# OAK
# WAS
# CHA
# SLN
# CHN
# BOS
# MIA
# HOU
# CLE

# %% [markdown]
# ### Augment our main DataFrame

# %%
# Again, we iterate through the main dataframe
# get the team, season, game and then get
# the relevant info from the odds dictionary

implied_prob_h = np.zeros(df.shape[0])
implied_prob_v = np.zeros(df.shape[0])
over_under = np.zeros(df.shape[0])
ou_result = np.full(df.shape[0],'', dtype=object)
for ind, row in df.iterrows():
    if (ind%1000)==0:
        print(ind)
    if row.season<2019:
        continue
    else:
        season = row['season']
        home_team = row['team_h']
        visit_team = row['team_v']
        home_game_no = row['game_no_h']
        visit_game_no = row['game_no_v']
        date_dblh = row['date_dblhead']
        try:
            implied_prob_h[ind] = df_odds_dict[home_team][season].loc[date_dblh,'prob_implied']
            over_under[ind] = df_odds_dict[home_team][season].loc[date_dblh,'Total']
            ou_result[ind] = df_odds_dict[home_team][season].loc[date_dblh,'OU']
        except KeyError:
            print(f'Game not found wrt home_team:{home_team} vs {visit_team} date_dbl {date_dblh}')
        try:
            implied_prob_v[ind] = df_odds_dict[visit_team][season].loc[date_dblh,'prob_implied']
        except KeyError:
            print(f'Game not found wrt visit_team:{visit_team} vs {home_team} date_dbl {date_dblh}')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# Game not found wrt home_team:CHA vs SEA date_dbl 202106260
# Game not found wrt visit_team:SEA vs CHA date_dbl 202106260
# Game not found wrt home_team:ATL vs SDN date_dbl 202107211
# Game not found wrt visit_team:SDN vs ATL date_dbl 202107211
# Game not found wrt home_team:ATL vs SDN date_dbl 202107212
# Game not found wrt visit_team:SDN vs ATL date_dbl 202107212
# 93000
# 94000
# 95000
# 96000

# %%
df['implied_prob_h'] = implied_prob_h
df['implied_prob_v'] = implied_prob_v
df['implied_prob_h_mid'] = (implied_prob_h + (1-implied_prob_v))/2
df['over_under_line']=over_under
df['over_under_result']=ou_result

# %% [markdown]
# ### Drop 3 games with no odds

# %%
df[(df.season>=2019) & (df.implied_prob_h==0)]
# Out:
#            date  dblheader_code day_of_week team_v league_v  game_no_v team_h  \
# 92555  20210626               0         Sat    SEA       AL         78    CHA
# 92838  20210721               1         Wed    SDN       NL         98    ATL
# 92839  20210721               2         Wed    SDN       NL         99    ATL
#
#       league_h  game_no_h  runs_v  runs_h  outs_total day_night  \
# 92555       AL         76       3       2          54         D
# 92838       NL         94       3       2          42         D
# 92839       NL         95       6       5          42         N
#
#              completion_info forfeit_info protest_info ballpark_id  \
# 92555  20210627,CHI12,0,0,15          NaN          NaN       CHI12
# 92838                    NaN          NaN          NaN       ATL03
# 92839  20210924,SAN02,5,4,27          NaN          NaN       ATL03
#
#        attendance  game_minutes linescore_v linescore_h  AB_v  H_v  2B_v  \
# 92555     30017.0           197   000011001   000011000    34    7     0
# 92838     28621.0           156     0001200     0000020    26    7     2
# 92839        -1.0           126     4100001     0400010    26    6     2
#
#        3B_v  HR_v  RBI_v  SH_v  SF_v  HBP_v  BB_v  IBB_v  SO_v  SB_v  CS_v  \
# 92555     0     3      3     0     0      0     3      0     9     0     0
# 92838     0     1      3     0     1      0     4      0     6     0     1
# 92839     0     1      5     0     1      0     6      2     7     1     0
#
#        GIDP_v  CI_v  LOB_v  P_num_v  ERind_v  ERteam_v  WP_v  balk_v  PO_v  \
# 92555       1     0      7        7        2         2     0       0    27
# 92838       0     0      7        3        1         1     0       0    21
# 92839       0     0      6        7        5         5     0       0    21
#
#        ASST_v  ERR_v  PB_v  DP_v  TP_v  AB_h  H_h  2B_h  3B_h  HR_h  RBI_h  \
# 92555       9      0     0     3     0    29    6     0     0     0      2
# 92838      10      1     1     0     0    25    5     1     0     0      1
# 92839       5      0     0     1     0    24    5     2     0     1      5
#
#        SH_h  SF_h  HBP_h  BB_h  IBB_h  SO_h  SB_h  CS_h  GIDP_h  CI_h  LOB_h  \
# 92555     0     1      1     3      0    11     1     0       3     0      5
# 92838     1     1      0     0      0     3     0     0       0     0      4
# 92839     0     1      0     6      0     6     0     0       1     0      5
#
#        P_num_h  ERind_h  ERteam_h  WP_h  balk_h  PO_h  ASST_h  ERR_h  PB_h  \
# 92555        3        3         3     0       0    27       7      1     0
# 92838        3        3         3     2       0    21       8      0     0
# 92839        4        6         6     2       0    21       7      0     0
#
#        DP_h  TP_h ump_HB_id    ump_HB_name ump_1B_id   ump_1B_name ump_2B_id  \
# 92555     1     0  cuzzp901     Phil Cuzzi  hallt901   Tom Hallion  rippm901
# 92838     0     0  timmt901    Tim Timmons  riggj901  Jeremy Riggs  mahrn901
# 92839     0     0  torrc901  Carlos Torres  mahrn901  Nick Mahrley  marqa901
#
#            ump_2B_name ump_3B_id      ump_3B_name ump_LF_id ump_LF_name  \
# 92555   Mark Ripperger  blasc901      Cory Blaser       NaN      (none)
# 92838     Nick Mahrley  marqa901  Alfonso Marquez       NaN      (none)
# 92839  Alfonso Marquez  riggj901     Jeremy Riggs       NaN      (none)
#
#       ump_RF_id ump_RF_name  mgr_id_v     mgr_name_v  mgr_id_h     mgr_name_h  \
# 92555       NaN      (none)  servs002  Scott Servais  larut101   Tony LaRussa
# 92838       NaN      (none)  tingj801  Jayce Tingler  snitb801  Brian Snitker
# 92839       NaN      (none)  tingj801  Jayce Tingler  snitb801  Brian Snitker
#
#       pitcher_id_w pitcher_name_w pitcher_id_l pitcher_name_l pitcher_id_s  \
# 92555     sewap001    Paul Sewald     hendl001  Liam Hendriks     gravk001
# 92838     paddc001  Chris Paddack     mullk001    Kyle Muller     melam001
# 92839     hudsd001  Daniel Hudson     smitw002     Will Smith     melam001
#
#          pitcher_name_s  GWRBI_id       GWRBI_name pitcher_start_id_v  \
# 92555  Kendall Graveman  tramt001  Taylor Trammell           gilbl002
# 92838     Mark Melancon  kim-h002     Ha-Seong Kim           paddc001
# 92839     Mark Melancon  tatif002   Fernando Tatis           knehr001
#
#       pitcher_start_name_v pitcher_start_id_h pitcher_start_name_h  \
# 92555        Logan Gilbert           lynnl001           Lance Lynn
# 92838        Chris Paddack           mullk001          Kyle Muller
# 92839          Reiss Knehr           wilsb003         Bryse Wilson
#
#       batter1_name_v   batter1_id_v  batter1_pos_v batter2_name_v  \
# 92555       crawj002  J.P. Crawford              6       hanim001
# 92838       phamt001     Tommy Pham              7       tatif002
# 92839       grist001  Trent Grisham              8       tatif002
#
#          batter2_id_v  batter2_pos_v batter3_name_v      batter3_id_v  \
# 92555   Mitch Haniger              9       seagk001       Kyle Seager
# 92838  Fernando Tatis              6       cronj001  Jake Cronenworth
# 92839  Fernando Tatis              6       cronj001  Jake Cronenworth
#
#        batter3_pos_v batter4_name_v   batter4_id_v  batter4_pos_v  \
# 92555              5       frant002      Ty France              3
# 92838              3       machm001  Manny Machado              5
# 92839              4       hosme001    Eric Hosmer              3
#
#       batter5_name_v batter5_id_v  batter5_pos_v batter6_name_v  \
# 92555       bauej001  Jake Bauers              7       longs001
# 92838       myerw001    Wil Myers              9       profj001
# 92839       myerw001    Wil Myers              9       profj001
#
#            batter6_id_v  batter6_pos_v batter7_name_v  batter7_id_v  \
# 92555         Shed Long              4       torrl001  Luis Torrens
# 92838  Jurickson Profar              8       kim-h002  Ha-Seong Kim
# 92839  Jurickson Profar              7       kim-h002  Ha-Seong Kim
#
#        batter7_pos_v batter8_name_v     batter8_id_v  batter8_pos_v  \
# 92555              2       fralj001      Jake Fraley             10
# 92838              4       rivaw001    Webster Rivas              2
# 92839              5       carav001  Victor Caratini              2
#
#       batter9_name_v     batter9_id_v  batter9_pos_v batter1_name_h  \
# 92555       tramt001  Taylor Trammell              8       andet001
# 92838       paddc001    Chris Paddack              1       pedej001
# 92839       knehr001      Reiss Knehr              1       pedej001
#
#        batter1_id_h  batter1_pos_h batter2_name_h    batter2_id_h  \
# 92555  Tim Anderson              6       goodb001   Brian Goodwin
# 92838  Joc Pederson              9       swand001  Dansby Swanson
# 92839  Joc Pederson              9       swand001  Dansby Swanson
#
#        batter2_pos_h batter3_name_h     batter3_id_h  batter3_pos_h  \
# 92555              8       moncy001     Yoan Moncada              5
# 92838              6       freef001  Freddie Freeman              3
# 92839              6       freef001  Freddie Freeman              3
#
#       batter4_name_h  batter4_id_h  batter4_pos_h batter5_name_h  \
# 92555       abrej003    Jose Abreu              3       grany001
# 92838       albio001  Ozzie Albies              4       rilea001
# 92839       albio001  Ozzie Albies              4       rilea001
#
#           batter5_id_h  batter5_pos_h batter6_name_h       batter6_id_h  \
# 92555  Yasmani Grandal              2       lambj001          Jake Lamb
# 92838     Austin Riley              5       hereg002  Guillermo Heredia
# 92839     Austin Riley              5       vogts001       Stephen Vogt
#
#        batter6_pos_h batter7_name_h       batter7_id_h  batter7_pos_h  \
# 92555              7       mercy001    Yermin Mercedes             10
# 92838              8       arcio002      Orlando Arcia              7
# 92839              2       hereg002  Guillermo Heredia              8
#
#       batter8_name_h   batter8_id_h  batter8_pos_h batter9_name_h  \
# 92555       garcl004   Leury Garcia              4       gonzl005
# 92838       smitk002    Kevan Smith              2       mullk001
# 92839       arcio002  Orlando Arcia              7       wilsb003
#
#         batter9_id_h  batter9_pos_h  \
# 92555  Luis Gonzalez              9
# 92838    Kyle Muller              1
# 92839   Bryse Wilson              1
#
#                                                misc_info acqui_info  season  \
# 92555                         umpchange,3,ump1b,clemp901          Y    2021
# 92838                                                NaN          Y    2021
# 92839  umpchange,5,umphome,ticht901,5,ump1b,littw901,...          Y    2021
#
#        run_diff  home_victory  run_total  date_dblhead  BATAVG_162_h  \
# 92555        -1             0          5     202106260      0.261093
# 92838        -1             0          5     202107211      0.250874
# 92839        -1             0         11     202107212      0.250414
#
#        BATAVG_162_v  OBP_162_h  OBP_162_v  SLG_162_h  SLG_162_v  OBS_162_h  \
# 92555      0.220639   0.327324   0.292443   0.433627   0.372102   0.760951
# 92838      0.248832   0.326777   0.323520   0.447673   0.429105   0.774450
# 92839      0.249205   0.326105   0.324069   0.446511   0.430496   0.772616
#
#        OBS_162_v  SB_162_h  SB_162_v  CS_162_h  CS_162_v  ERR_162_h  \
# 92555   0.664545      56.0     104.0      27.0      34.0      102.0
# 92838   0.752625      69.0     146.0      20.0      40.0       85.0
# 92839   0.754565      69.0     146.0      20.0      41.0       85.0
#
#        ERR_162_v  BATAVG_30_h  BATAVG_30_v  OBP_30_h  OBP_30_v  SLG_30_h  \
# 92555       81.0     0.239378     0.243539  0.314019  0.301194  0.383420
# 92838       99.0     0.248227     0.277168  0.326067  0.352100  0.427558
# 92839      100.0     0.246926     0.280561  0.323827  0.357782  0.425205
#
#        SLG_30_v  OBS_30_h  OBS_30_v  SB_30_h  SB_30_v  CS_30_h  CS_30_v  \
# 92555  0.410537  0.697438  0.711731     11.0     15.0      7.0      5.0
# 92838  0.499501  0.753625  0.851602     19.0     22.0      6.0      9.0
# 92839  0.504008  0.749032  0.861790     18.0     22.0      6.0     10.0
#
#        ERR_30_h  ERR_30_v  implied_prob_h  implied_prob_v  implied_prob_h_mid  \
# 92555      18.0      15.0             0.0             0.0                 0.5
# 92838       8.0      18.0             0.0             0.0                 0.5
# 92839       8.0      19.0             0.0             0.0                 0.5
#
#        over_under_line over_under_result
# 92555              0.0
# 92838              0.0
# 92839              0.0

# %%
indices_to_drop = df[(df.season>=2019) & (df.implied_prob_h==0)].index
indices_to_drop
# Out:
# Int64Index([92555, 92838, 92839], dtype='int64')

# %%
df.shape
# Out:
# (96276, 199)

# %%
df.drop(indices_to_drop, inplace=True)
df.shape
# Out:
# (96273, 199)

# %%
df.reset_index(inplace=True, drop=True)
df.shape
# Out:
# (96273, 199)

# %%
df.to_csv('df_bp3.csv', index=False)
