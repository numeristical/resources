# %% [markdown]
# ## Runs Scored - Model Evaluation
# - ### Last time we built a model to predict runs scored given features about the hitting team and the opposing pitchers
# - ### In this lesson we will use that model to predict the probability that the total runs scored is over or under the "over/under line" for each game in the test set
# - ### This first attempt involves an independence assumption which is likely not true in practice, but may be close enough to true to give good predictions
# - ### We will then evaluate how this model would have fared in practice had we made bets on it, and do some further analysis to see if we really have an edge on the Vegas probabilities for the over/under

# %%
## Upgrade to the latest version of structureboost
## should be >= 0.4.1
## !pip install --upgrade structureboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import structureboost as stb
import ml_insights as mli
import scipy as sp

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
stb.__version__
# Out:
# '0.4.1'

# %%
df=pd.read_csv('df_bp9.csv')
df_runs=pd.read_csv('df_runs_bp11.csv')
# Out:
# /Users/brianlucena/.pyenv/versions/3.9.13/envs/ds3913/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3398: DtypeWarning: Columns (13,14,15,19,85,87,159,206) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/brianlucena/.pyenv/versions/3.9.13/envs/ds3913/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3398: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.over_under_line.max()
# Out:
# 15.0

# %%
df_runs['runs_trunc'] = np.minimum(df_runs['runs'],16)

# %%
df_train = df_runs[(df_runs.season>1980) & (df_runs.season<=2018) & ~(df_runs.OBP_162.isnull())]
df_valid = df_runs[(df_runs.season>=2019) & (df_runs.season<=2020)]
df_test = df_runs[df_runs.season>=2021]

# %%
df_test_game = df[df.season>=2021]

# %% [markdown]
# ## Begin Modeling

# %%
df_runs.head()
# Out:
#    season      date  dblheader_code  date_dblhead team_h team_v league_h  \
# 0    1980  19800409               0     198004090    SEA    TOR       AL
# 1    1980  19800409               0     198004090    CIN    ATL       NL
# 2    1980  19800410               0     198004100    CHA    BAL       AL
# 3    1980  19800410               0     198004100    KCA    DET       AL
# 4    1980  19800410               0     198004100    MIL    BOS       AL
#
#   league_v  over_under_line over_under_result ballpark_id day_night  runs  \
# 0       AL              0.0               NaN       SEA02         N     8
# 1       NL              0.0               NaN       CIN08         D     9
# 2       AL              0.0               NaN       CHI10         D     3
# 3       AL              0.0               NaN       KAN06         N     1
# 4       AL              0.0               NaN       MIL05         D     9
#
#    BATAVG_30  OBP_30  SLG_30  OBS_30  ERR_30  SB_30  CS_30  BATAVG_162  \
# 0        NaN     NaN     NaN     NaN     NaN    NaN    NaN         NaN
# 1        NaN     NaN     NaN     NaN     NaN    NaN    NaN         NaN
# 2        NaN     NaN     NaN     NaN     NaN    NaN    NaN         NaN
# 3        NaN     NaN     NaN     NaN     NaN    NaN    NaN         NaN
# 4        NaN     NaN     NaN     NaN     NaN    NaN    NaN         NaN
#
#    OBP_162  SLG_162  OBS_162  ERR_162  SB_162  CS_162  lineup8_BATAVG_30  \
# 0      NaN      NaN      NaN      NaN     NaN     NaN           0.258957
# 1      NaN      NaN      NaN      NaN     NaN     NaN           0.291169
# 2      NaN      NaN      NaN      NaN     NaN     NaN           0.263922
# 3      NaN      NaN      NaN      NaN     NaN     NaN           0.298410
# 4      NaN      NaN      NaN      NaN     NaN     NaN           0.296312
#
#    lineup9_BATAVG_30  lineup8_BATAVG_30_w  lineup9_BATAVG_30_w  \
# 0           0.244999             0.261081             0.248690
# 1           0.266224             0.291499             0.269692
# 2           0.267004             0.264340             0.266991
# 3           0.292733             0.299887             0.294787
# 4           0.285847             0.297950             0.288656
#
#    lineup8_OBP_30  lineup9_OBP_30  lineup8_OBP_30_w  lineup9_OBP_30_w  \
# 0        0.316389        0.299753          0.318195          0.303498
# 1        0.358840        0.326376          0.359266          0.330886
# 2        0.310496        0.313034          0.311517          0.313633
# 3        0.355706        0.350287          0.356855          0.352013
# 4        0.363794        0.351150          0.364534          0.353425
#
#    lineup8_SLG_30  lineup9_SLG_30  lineup8_SLG_30_w  lineup9_SLG_30_w  \
# 0        0.391599        0.366607          0.393452          0.371455
# 1        0.443534        0.401660          0.443099          0.406587
# 2        0.390244        0.388551          0.390049          0.388589
# 3        0.453274        0.441142          0.454150          0.443474
# 4        0.485131        0.458414          0.487130          0.463614
#
#    lineup8_OBS_30  lineup9_OBS_30  lineup8_OBS_30_w  lineup9_OBS_30_w  \
# 0        0.707988        0.666360          0.711647          0.674953
# 1        0.802374        0.728036          0.802365          0.737473
# 2        0.700740        0.701584          0.701566          0.702222
# 3        0.808981        0.791429          0.811005          0.795487
# 4        0.848924        0.809564          0.851665          0.817039
#
#    lineup8_SLGmod_30  lineup9_SLGmod_30  lineup8_SLGmod_30_w  \
# 0           0.302610           0.283802             0.301660
# 1           0.368370           0.345959             0.367210
# 2           0.260106           0.256259             0.260372
# 3           0.343886           0.346380             0.343042
# 4           0.393482           0.369762             0.392834
#
#    lineup9_SLGmod_30_w  lineup8_SObat_perc_30  lineup9_SObat_perc_30  \
# 0             0.285333               0.103902               0.099765
# 1             0.347758               0.135716               0.139155
# 2             0.256989               0.077394               0.078598
# 3             0.345302               0.122739               0.131104
# 4             0.372190               0.131255               0.125560
#
#    lineup8_SObat_perc_30_w  lineup9_SObat_perc_30_w  lineup8_BATAVG_75  \
# 0                 0.103370                 0.099810           0.247605
# 1                 0.135119                 0.138179           0.288886
# 2                 0.077651                 0.078677           0.241068
# 3                 0.122575                 0.129893           0.274940
# 4                 0.130959                 0.126016           0.288058
#
#    lineup9_BATAVG_75  lineup8_BATAVG_75_w  lineup9_BATAVG_75_w  \
# 0           0.241513             0.247225             0.241943
# 1           0.259751             0.289169             0.263708
# 2           0.243942             0.242439             0.244814
# 3           0.273803             0.276908             0.275724
# 4           0.286735             0.289063             0.287811
#
#    lineup8_OBP_75  lineup9_OBP_75  lineup8_OBP_75_w  lineup9_OBP_75_w  \
# 0        0.302829        0.293223          0.301952          0.293652
# 1        0.360925        0.323785          0.361099          0.328661
# 2        0.288707        0.292852          0.289989          0.293482
# 3        0.338685        0.336061          0.340145          0.337713
# 4        0.346656        0.343273          0.347110          0.344112
#
#    lineup8_SLG_75  lineup9_SLG_75  lineup8_SLG_75_w  lineup9_SLG_75_w  \
# 0        0.357380        0.344445          0.356761          0.345529
# 1        0.441471        0.395382          0.441546          0.401305
# 2        0.367696        0.368010          0.369703          0.369782
# 3        0.422740        0.415529          0.425510          0.418947
# 4        0.484713        0.473162          0.486696          0.476420
#
#    lineup8_OBS_75  lineup9_OBS_75  lineup8_OBS_75_w  lineup9_OBS_75_w  \
# 0        0.660209        0.637667          0.658713          0.639181
# 1        0.802396        0.719167          0.802645          0.729966
# 2        0.656403        0.660861          0.659691          0.663264
# 3        0.761426        0.751591          0.765656          0.756660
# 4        0.831369        0.816434          0.833806          0.820533
#
#    lineup8_SLGmod_75  lineup9_SLGmod_75  lineup8_SLGmod_75_w  \
# 0           0.277352           0.272526             0.275707
# 1           0.361697           0.328916             0.361180
# 2           0.278640           0.274949             0.279360
# 3           0.338469           0.336376             0.338461
# 4           0.386489           0.371213             0.386952
#
#    lineup9_SLGmod_75_w  lineup8_SObat_perc_75  lineup9_SObat_perc_75  \
# 0             0.271654               0.101148               0.107454
# 1             0.332614               0.124103               0.117721
# 2             0.276068               0.097833               0.094696
# 3             0.336635               0.118041               0.123190
# 4             0.373573               0.125583               0.122170
#
#    lineup8_SObat_perc_75_w  lineup9_SObat_perc_75_w  lineup8_BATAVG_162  \
# 0                 0.100206                 0.105801            0.236959
# 1                 0.123917                 0.118364            0.285461
# 2                 0.097809                 0.095073            0.223431
# 3                 0.117667                 0.122199            0.278708
# 4                 0.125610                 0.122628            0.281458
#
#    lineup9_BATAVG_162  lineup8_BATAVG_162_w  lineup9_BATAVG_162_w  \
# 0            0.232164              0.235594              0.231540
# 1            0.255115              0.286005              0.259461
# 2            0.229971              0.227209              0.232552
# 3            0.276223              0.280052              0.277753
# 4            0.282525              0.282189              0.283049
#
#    lineup8_OBP_162  lineup9_OBP_162  lineup8_OBP_162_w  lineup9_OBP_162_w  \
# 0         0.293375         0.284567           0.291567           0.284053
# 1         0.360618         0.321921           0.360532           0.326760
# 2         0.271952         0.278582           0.276265           0.281634
# 3         0.340390         0.336716           0.341544           0.338225
# 4         0.348352         0.347186           0.348650           0.347603
#
#    lineup8_SLG_162  lineup9_SLG_162  lineup8_SLG_162_w  lineup9_SLG_162_w  \
# 0         0.341385         0.330441           0.339080           0.329750
# 1         0.430153         0.383730           0.431204           0.390577
# 2         0.336790         0.340984           0.341612           0.344806
# 3         0.425614         0.415831           0.427539           0.418812
# 4         0.465148         0.456431           0.466341           0.458616
#
#    lineup8_OBS_162  lineup9_OBS_162  lineup8_OBS_162_w  lineup9_OBS_162_w  \
# 0         0.634760         0.615009           0.630646           0.613803
# 1         0.790771         0.705651           0.791736           0.717337
# 2         0.608742         0.619566           0.617877           0.626440
# 3         0.766004         0.752547           0.769083           0.757037
# 4         0.813500         0.803617           0.814990           0.806219
#
#    lineup8_SLGmod_162  lineup9_SLGmod_162  lineup8_SLGmod_162_w  \
# 0            0.271778            0.267889              0.269267
# 1            0.361987            0.325196              0.361230
# 2            0.263630            0.260493              0.265748
# 3            0.345607            0.340041              0.345471
# 4            0.388563            0.373005              0.387968
#
#    lineup9_SLGmod_162_w  lineup8_SObat_perc_162  lineup9_SObat_perc_162  \
# 0              0.266116                0.101146                0.108100
# 1              0.329186                0.128171                0.117359
# 2              0.262804                0.093928                0.092464
# 3              0.340625                0.126281                0.129061
# 4              0.374445                0.130409                0.126275
#
#    lineup8_SObat_perc_162_w  lineup9_SObat_perc_162_w  lineup8_BATAVG_350  \
# 0                  0.099922                  0.106111            0.207199
# 1                  0.127703                  0.118310            0.267083
# 2                  0.094230                  0.092923            0.177737
# 3                  0.125743                  0.128222            0.252866
# 4                  0.129788                  0.126240            0.276456
#
#    lineup9_BATAVG_350  lineup8_BATAVG_350_w  lineup9_BATAVG_350_w  \
# 0            0.203860              0.206608              0.203750
# 1            0.238042              0.268944              0.243412
# 2            0.188206              0.181496              0.190270
# 3            0.241595              0.254425              0.244435
# 4            0.275628              0.276774              0.276020
#
#    lineup8_OBP_350  lineup9_OBP_350  lineup8_OBP_350_w  lineup9_OBP_350_w  \
# 0         0.259931         0.254701           0.258950           0.254479
# 1         0.340819         0.303585           0.342243           0.309602
# 2         0.219227         0.230336           0.223590           0.232864
# 3         0.317514         0.304615           0.318754           0.307374
# 4         0.340522         0.338171           0.340211           0.338189
#
#    lineup8_SLG_350  lineup9_SLG_350  lineup8_SLG_350_w  lineup9_SLG_350_w  \
# 0         0.296881         0.288656           0.295494           0.288449
# 1         0.407468         0.362828           0.409707           0.370522
# 2         0.265545         0.274913           0.270313           0.278029
# 3         0.384813         0.364437           0.387365           0.369330
# 4         0.450514         0.441568           0.450465           0.442660
#
#    lineup8_OBS_350  lineup9_OBS_350  lineup8_OBS_350_w  lineup9_OBS_350_w  \
# 0         0.556812         0.543357           0.554444           0.542928
# 1         0.748286         0.666413           0.751951           0.680124
# 2         0.484772         0.505249           0.493903           0.510892
# 3         0.702327         0.669052           0.706119           0.676704
# 4         0.791036         0.779739           0.790675           0.780849
#
#    lineup8_SLGmod_350  lineup9_SLGmod_350  lineup8_SLGmod_350_w  \
# 0            0.243524            0.242021              0.241553
# 1            0.358024            0.319830              0.358716
# 2            0.215457            0.215653              0.218230
# 3            0.320240            0.306563              0.320480
# 4            0.380242            0.366133              0.378797
#
#    lineup9_SLGmod_350_w  lineup8_SObat_perc_350  lineup9_SObat_perc_350  \
# 0              0.240432                0.092185                0.098451
# 1              0.325308                0.133727                0.120456
# 2              0.218132                0.080041                0.079977
# 3              0.308517                0.117394                0.115144
# 4              0.366620                0.135344                0.130341
#
#    lineup8_SObat_perc_350_w  lineup9_SObat_perc_350_w  Strt_ERA_10  \
# 0                  0.091244                  0.096804     5.692771
# 1                  0.134185                  0.122555     2.464286
# 2                  0.081004                  0.080855     3.338710
# 3                  0.116791                  0.114885     2.649533
# 4                  0.134938                  0.130610     3.054299
#
#    Strt_WHIP_10  Strt_SO_perc_10  Strt_H_BB_perc_10  Strt_TB_BB_perc_10  \
# 0      1.572289         0.104418           0.349398            0.502008
# 1      1.035714         0.173134           0.259701            0.414925
# 2      1.193548         0.113725           0.290196            0.431373
# 3      1.163551         0.155709           0.287197            0.380623
# 4      1.126697         0.156146           0.275748            0.355482
#
#    Strt_FIP_10  Strt_FIP_perc_10  Strt_ERA_35  Strt_WHIP_35  Strt_SO_perc_35  \
# 0     5.186747          1.152610     3.857143      1.357945         0.115165
# 1     3.738095          0.937313     3.358852      1.209330         0.149871
# 2     4.322581          1.050980     2.778364      1.163588         0.107317
# 3     3.140187          0.775087     3.409289      1.258345         0.135079
# 4     2.809955          0.687708     2.822418      1.163728         0.150508
#
#    Strt_H_BB_perc_35  Strt_TB_BB_perc_35  Strt_FIP_35  Strt_FIP_perc_35  \
# 0           0.321551            0.434436     4.040128          0.956670
# 1           0.290267            0.417743     3.918660          0.940568
# 2           0.286829            0.375610     3.649077          0.899512
# 3           0.302618            0.405236     3.840348          0.923560
# 4           0.284395            0.411819     3.732997          0.912281
#
#    Strt_ERA_75  Strt_WHIP_75  Strt_SO_perc_75  Strt_H_BB_perc_75  \
# 0     4.644315      1.460641         0.098187           0.336354
# 1     3.164550      1.214203         0.156741           0.289909
# 2     2.759008      1.171294         0.117082           0.288772
# 3     3.658397      1.302481         0.129098           0.310792
# 4     3.061692      1.198590         0.151064           0.289362
#
#    Strt_TB_BB_perc_75  Strt_FIP_75  Strt_FIP_perc_75  Bpen_WHIP_10  \
# 0            0.459215     4.723032          1.087613           1.5
# 1            0.402399     3.545612          0.846567           1.5
# 2            0.377021     3.370348          0.830931           1.5
# 3            0.413251     3.979008          0.949454           1.5
# 4            0.422128     3.879553          0.936596           1.5
#
#    Bpen_SO_perc_10  Bpen_H_BB_perc_10  Bpen_TB_BB_perc_10  Bpen_WHIP_35  \
# 0              0.2               0.37                0.45           1.5
# 1              0.2               0.37                0.45           1.5
# 2              0.2               0.37                0.45           1.5
# 3              0.2               0.37                0.45           1.5
# 4              0.2               0.37                0.45           1.5
#
#    Bpen_SO_perc_35  Bpen_H_BB_perc_35  Bpen_TB_BB_perc_35  Bpen_WHIP_75  \
# 0              0.2               0.37                0.45           1.5
# 1              0.2               0.37                0.45           1.5
# 2              0.2               0.37                0.45           1.5
# 3              0.2               0.37                0.45           1.5
# 4              0.2               0.37                0.45           1.5
#
#    Bpen_SO_perc_75  Bpen_H_BB_perc_75  Bpen_TB_BB_perc_75  home_hitting  \
# 0              0.2               0.37                0.45             1
# 1              0.2               0.37                0.45             1
# 2              0.2               0.37                0.45             1
# 3              0.2               0.37                0.45             1
# 4              0.2               0.37                0.45             1
#
#    runs_trunc
# 0           8
# 1           9
# 2           3
# 3           1
# 4           9

# %%
feat_set = ['OBP_162',
 'SLG_162',
 'Strt_WHIP_35',
 'Strt_TB_BB_perc_35',
 'Strt_H_BB_perc_35',
 'Strt_SO_perc_10',
 'Bpen_WHIP_75',
 'Bpen_TB_BB_perc_75',
 'Bpen_H_BB_perc_75',
 'Bpen_SO_perc_75',
 'Bpen_WHIP_35',
 'Bpen_TB_BB_perc_35',
 'Bpen_H_BB_perc_35',
 'Bpen_SO_perc_35',
 'Bpen_WHIP_10',
 'Bpen_TB_BB_perc_10',
 'Bpen_H_BB_perc_10',
 'Bpen_SO_perc_10',
 'lineup9_OBP_162',
 'lineup9_SLG_162',
 'home_hitting']

# %%
bpv2 = np.linspace(-.5,16.5,18)
bpv2
# Out:
# array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5,
#        10.5, 11.5, 12.5, 13.5, 14.5, 15.5, 16.5])

# %%
# def try_features_runs(feat_set, max_depth=2):
target = 'runs_trunc'
X_train = df_train.loc[:,feat_set]
X_valid = df_valid.loc[:,feat_set]
X_test = df_test.loc[:,feat_set]

y_train = df_train[target].to_numpy()
y_valid = df_valid[target].to_numpy()
y_test = df_test[target].to_numpy()

# %%
cr1 = stb.Coarsage(num_trees = 1000, learning_rate=.02, max_depth=4,
                  binpt_method = 'fixed', 
               binpt_vec=bpv2)
cr1.fit(X_train, y_train, eval_set=(X_valid, y_valid), early_stop_past_steps=5, eval_freq=10)
# Out:
# i=0, eval_set_loss = 2.4990192148502604
# i=10, eval_set_loss = 2.495524528841559
# i=20, eval_set_loss = 2.4930883144691935
# i=30, eval_set_loss = 2.491326254878249
# i=40, eval_set_loss = 2.4899476910775844
# i=50, eval_set_loss = 2.488865655337549
# i=60, eval_set_loss = 2.4881122345957767
# i=70, eval_set_loss = 2.4875551629313724
# i=80, eval_set_loss = 2.4867541553427266
# i=90, eval_set_loss = 2.4861089626610164
# i=100, eval_set_loss = 2.4856129551188397
# i=110, eval_set_loss = 2.4852459601878563
# i=120, eval_set_loss = 2.4848450037372696
# i=130, eval_set_loss = 2.484570981189364
# i=140, eval_set_loss = 2.4843866588982384
# i=150, eval_set_loss = 2.48423577145035
# i=160, eval_set_loss = 2.4841363963915764
# i=170, eval_set_loss = 2.484191076760697
# i=180, eval_set_loss = 2.4841887161870644
# i=190, eval_set_loss = 2.4841880679643458
# i=200, eval_set_loss = 2.4841601239822046
# i=210, eval_set_loss = 2.484205814406579
# Stopping early: low pt was 5 steps ago

# %%
preds_test = cr1.predict_distributions(X_test)

# %%
preds_test.log_loss(y_test)
# Out:
# 2.4258100625716272

# %%
plt.figure(figsize=(15,15))
for i in range(1,7):
    plt.subplot(3,2,i)
    preds_test[i].plot_density()
    plt.vlines(x=y_test[i], ymin=0,ymax=.1, color='k', linestyle='--')

# %% [markdown]
# ## Predicting the Over / Under
# - ### As a first step, we will model the total score as an **independent** sum of the two scores
# - ### For baseball, this is not a terrible assumption (would be worse in other sports)
# - ### Still, would expect some imperfection, since teams make strategic decisions based on the score of the game
#     - ### Play for one run in a close game
#     - ### Put a rookie pitcher in with a big lead

# %%
def probs_oup_val(probvec_a, probvec_b, val, ties_go_over=True):
    """given two probability distributions and the ou-line, returns prob of under"""
    val_up = int(np.ceil(val))
    val_down = int(np.floor(val))
    cdf_b = np.cumsum(probvec_b)
    prob_under = 0
    prob_push = 0
    if (val_down<val_up): # This means we have a decimal (.5) o/u value - no pushes      
        for i in range(0, val_down+1):
            # calculate prob that we are less than or equal to val_down for each
            # value of probvec_a between 0 and val_down
            prob_under += probvec_a[i] * cdf_b[val_down-i]
        return(1-prob_under-prob_push, prob_under, prob_push)
    else: # This means val_down == val_up == val and we have an integer line so pushes are possible
        for i in range(0, val_down):
            # calculate prob that we are less than or equal to val_down-1 for each
            # value of probvec_a between 0 and val_down
            prob_under += probvec_a[i] * cdf_b[val_down-1-i]
        for j in range(0, val_down+1):
            # calculate prob that we are exactly = val_down
            if (not ties_go_over) or (j != val_down-j): # if line is 10 and predicts score of 5-5, maybe count as over
                prob_push += probvec_a[j] * probvec_b[val_down-j] 
        return(1-prob_under-prob_push, prob_under,  prob_push)

# %%
num_games_test=int(df_test.shape[0]/2)

# %%
oup_probs = np.array([probs_oup_val(preds_test[i].probvec, preds_test[i+num_games_test].probvec, df_test.over_under_line.iloc[i])
                        for i in range(num_games_test)])

# %%
oup_probs[:5,:]
# Out:
# array([[0.67348759, 0.32651241, 0.        ],
#        [0.42308594, 0.47752091, 0.09939316],
#        [0.2318583 , 0.70226633, 0.06587537],
#        [0.4885844 , 0.41201151, 0.09940409],
#        [0.4214188 , 0.5785812 , 0.        ]])

# %%
oup_probs.mean(axis=0)
# Out:
# array([0.44714768, 0.51160141, 0.04125091])

# %%
df_test.over_under_result.value_counts().sum(), df_test.over_under_result.value_counts()/df_test.over_under_result.value_counts().sum()
# Out:
# (9704,
#  U    0.485573
#  O    0.466818
#  P    0.047609
#  Name: over_under_result, dtype: float64)

# %%
plt.figure(figsize=(12,12))
plt.subplot(3,1,1)
plt.hist(oup_probs[:,0], np.linspace(0,1,101));
plt.subplot(3,1,2)
plt.hist(oup_probs[:,1], np.linspace(0,1,101));
plt.subplot(3,1,3)
plt.hist(oup_probs[:,2], np.linspace(0,1,101));

# %%
def evaluate_edge_probs(oupmat, edge, test_df_w_ouline):
    bet_under = (oupmat[:,1]/(oupmat[:,0] + oupmat[:,1])) > (.5 + edge)
    bet_over = (oupmat[:,0]/(oupmat[:,0] + oupmat[:,1])) > (.5 + edge)
    num_cases_under = np.sum(bet_under)
    num_cases_over = np.sum(bet_over)
    num_cases_total = num_cases_under + num_cases_over
    num_under_correct = (test_df_w_ouline.loc[bet_under,'over_under_result']=='U').sum()
    num_under_push = (test_df_w_ouline.loc[bet_under,'over_under_result']=='P').sum()
    num_over_correct = (test_df_w_ouline.loc[bet_over,'over_under_result']=='O').sum()
    num_over_push = (test_df_w_ouline.loc[bet_over,'over_under_result']=='P').sum()
    num_correct = num_under_correct + num_over_correct
    num_pushes = num_under_push + num_over_push
    num_incorrect = num_cases_total -num_correct - num_pushes
    pct_correct = num_correct / num_cases_total
    pct_pushes = num_pushes / num_cases_total
    pct_incorrect = num_incorrect / num_cases_total
    pct_under_correct = num_under_correct/num_cases_under
    pct_under_push = num_under_push/num_cases_under
    pct_over_correct = num_over_correct/num_cases_over
    pct_over_push = num_over_push/num_cases_over
    print(f'\nThere were {num_cases_total} games that met criteria of edge > {edge} ({num_cases_under} unders and {num_cases_over} overs)')
    print(f'Of them {num_correct} ({np.round(pct_correct,3)}) were correct (winning bets), ({num_under_correct} unders and {num_over_correct} overs) ')
    print(f'and {num_pushes} ({np.round(pct_pushes,3)}) were Pushes ({num_under_push} unders and {num_over_push} overs)')
    print(f'and {num_incorrect} ({np.round(pct_incorrect,3)}) were incorrect (losing bets))')
    winning_edge_m110 = pct_correct*1 + pct_incorrect*(-1.1)
    win_total_m110 = num_correct*1 + num_incorrect*(-1.1)
    print(f'Betting the Under at a line of -110, your profit would have been {np.round(winning_edge_m110,4)} per bet')
    print(f'\t for a total profit of {np.round(win_total_m110,2)} across all {num_cases_total} bets')
    print('\n')

# %%
for i in np.linspace(.25, .05,5):
    print(f'threshold = {i}')
    evaluate_edge_probs(oup_probs, i, df_test_game)
# Out:
# threshold = 0.25
#
# There were 78 games that met criteria of edge > 0.25 (71 unders and 7 overs)
# Of them 45 (0.577) were correct (winning bets), (41 unders and 4 overs)
# and 3 (0.038) were Pushes (2 unders and 1 overs)
# and 30 (0.385) were incorrect (losing bets))
# Betting the Under at a line of -110, your profit would have been 0.1538 per bet
# 	 for a total profit of 12.0 across all 78 bets
#
#
# threshold = 0.2
#
# There were 179 games that met criteria of edge > 0.2 (150 unders and 29 overs)
# Of them 96 (0.536) were correct (winning bets), (81 unders and 15 overs)
# and 7 (0.039) were Pushes (6 unders and 1 overs)
# and 76 (0.425) were incorrect (losing bets))
# Betting the Under at a line of -110, your profit would have been 0.0693 per bet
# 	 for a total profit of 12.4 across all 179 bets
#
#
# threshold = 0.15
#
# There were 355 games that met criteria of edge > 0.15 (280 unders and 75 overs)
# Of them 182 (0.513) were correct (winning bets), (145 unders and 37 overs)
# and 18 (0.051) were Pushes (16 unders and 2 overs)
# and 155 (0.437) were incorrect (losing bets))
# Betting the Under at a line of -110, your profit would have been 0.0324 per bet
# 	 for a total profit of 11.5 across all 355 bets
#
#
# threshold = 0.09999999999999998
#
# There were 994 games that met criteria of edge > 0.09999999999999998 (814 unders and 180 overs)
# Of them 489 (0.492) were correct (winning bets), (401 unders and 88 overs)
# and 47 (0.047) were Pushes (38 unders and 9 overs)
# and 458 (0.461) were incorrect (losing bets))
# Betting the Under at a line of -110, your profit would have been -0.0149 per bet
# 	 for a total profit of -14.8 across all 994 bets
#
#
# threshold = 0.05
#
# There were 2534 games that met criteria of edge > 0.05 (1935 unders and 599 overs)
# Of them 1229 (0.485) were correct (winning bets), (949 unders and 280 overs)
# and 124 (0.049) were Pushes (93 unders and 31 overs)
# and 1181 (0.466) were incorrect (losing bets))
# Betting the Under at a line of -110, your profit would have been -0.0277 per bet
# 	 for a total profit of -70.1 across all 2534 bets

# %%
def evaluate_lkratio(nc, ni, null_prob, alt_prob):
    null_lk = sp.stats.binom.pmf(nc,nc+ni,null_prob)
    alt_lk = sp.stats.binom.pmf(nc,nc+ni,alt_prob)
    return(alt_lk/null_lk)

# %%
evaluate_lkratio(45, 30, .5, 45/(45+30))
# Out:
# 4.527471049112594

# %%
evaluate_lkratio(96, 76, .5, 96/(96+76))
# Out:
# 3.2072866107201

# %%
evaluate_lkratio(182, 155, .5, 182/(155+182))
# Out:
# 2.95282544640109

# %%
evaluate_lkratio(489, 458, .5, 489/(489+458))
# Out:
# 1.6611039651274728

# %%
evaluate_lkratio(450, 300, .5, 45/(45+30))
# Out:
# 3618735.3177232626

# %% [markdown]
# ## Conclusions
# - ### Looks promising that our model *could* beat Vegas in the long run
# - ### Would like to see higher likelihood ratios to have more confidence
# - ### Let's repeat this notebook with more test data (less training data) to see if we can get more convicing evidence
